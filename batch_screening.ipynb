# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.Chem import Lipinski

# %%
molecules = pd.read_csv("molecules.csv")

# %%
results = []
for smi in molecules["smiles"]:
    result = analyze_molecule(smi)
    results.append(result)

results_df = pd.DataFrame(results)
results_df["name"] = molecules["name"]
results_df.to_excel("results.xlsx",index = False)
results_df.head()
# Out:
#                                          Descriptors  \
# 0  {'MW': 180.15899999999996, 'LogP': 1.3101, 'TP...
# 1  {'MW': 194.19399999999996, 'LogP': -1.0293, 'T...
# 2  {'MW': 206.28499999999997, 'LogP': 3.073200000...
# 3  {'MW': 151.165, 'LogP': 1.3505999999999998, 'T...
# 4  {'MW': 129.167, 'LogP': -1.034159999999999, 'T...
#
#                                             Lipinski  \
# 0  {'MW': True, 'LogP': True, 'HBA': True, 'HBD':...
# 1  {'MW': True, 'LogP': True, 'HBA': True, 'HBD':...
# 2  {'MW': True, 'LogP': True, 'HBA': True, 'HBD':...
# 3  {'MW': True, 'LogP': True, 'HBA': True, 'HBD':...
# 4  {'MW': True, 'LogP': True, 'HBA': True, 'HBD':...
#
#                                          Veber  \
# 0  {'TPSA': True, 'RB': True, 'OVERALL': True}
# 1  {'TPSA': True, 'RB': True, 'OVERALL': True}
# 2  {'TPSA': True, 'RB': True, 'OVERALL': True}
# 3  {'TPSA': True, 'RB': True, 'OVERALL': True}
# 4  {'TPSA': True, 'RB': True, 'OVERALL': True}
#
#                                                Ghose         name
# 0  {'MW': True, 'LogP': True, 'ATOM COUNT': False...      aspirin
# 1  {'MW': True, 'LogP': True, 'ATOM COUNT': False...     caffeine
# 2  {'MW': True, 'LogP': True, 'ATOM COUNT': False...    ibuprofen
# 3  {'MW': False, 'LogP': True, 'ATOM COUNT': Fals...  paracetamol
# 4  {'MW': False, 'LogP': True, 'ATOM COUNT': Fals...    metformin
