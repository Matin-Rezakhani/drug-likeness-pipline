# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.Chem import Lipinski

# %%
molecules = pd.read_csv("molecules.csv")

# %%
results = []
for smi in molecules["smiles"]:
    result = analyze_molecule(smi)
    results.append(result)

results_df = pd.DataFrame(results)
results_df["name"] = molecules["name"]
results_df.to_excel("results.xlsx",index = False)
results_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 results = []
#       2 for smi in molecules["smiles"]:
# ----> 3     result = analyze_molecule(smi)
#       4     results.append(result)
#       6 results_df = pd.DataFrame(results)
#
# NameError: name 'analyze_molecule' is not defined
